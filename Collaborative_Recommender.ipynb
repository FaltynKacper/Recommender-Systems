# %%
import pandas as pd
import numpy as np
import random
from surprise import dump
from surprise import SVD
from surprise import Dataset, Reader
from surprise import accuracy
from sklearn.metrics.pairwise import cosine_similarity

# %%
df_books = pd.read_csv('/.spyder-py3/files/input/books.csv')
df_books = df_books.drop_duplicates(subset = ['original_title'])
df_books = df_books.dropna(subset = ['original_title'])

# %%
df_ratings = pd.read_csv('/.spyder-py3/files/input/ratings.csv')
df_ratings = df_ratings.drop_duplicates()
df_ratings = df_ratings.dropna()

# %%
df_books = df_books[df_books.book_id.isin(df_ratings.book_id)]
df_ratings = df_ratings[df_ratings.book_id.isin(df_books.book_id)]

# %%
df = df_ratings.copy()

# %%
df = df.sample(frac = 1, random_state = 42)

threshold = int(.9 * len(df))
train_ratings = df[:threshold]
test_ratings = df[threshold:]                  

reader = Reader(rating_scale = (1, 5))
data = Dataset.load_from_df(train_ratings[['user_id','book_id','rating']], reader)

# %%
train_set = data.build_full_trainset()
#algo = SVD(n_epochs=10, verbose = True, random_state=42)
#algo.fit(train_set)


from surprise import dump
#dump.dump('/.spyder-py3/files/input/' + 'svd',algo = algo)
_, algo  = dump.load('/.spyder-py3/files/input/'  + 'svd')

# %%
test_data = Dataset.load_from_df(test_ratings[['user_id','book_id','rating']], reader).build_full_trainset()
test_set = test_data.build_testset()
predictions = algo.test(test_set)
print (accuracy.rmse(predictions))
# Out:
# RMSE: 0.8418
# 0.8418446275472864

# %%
id = 913
print('SVD Similar books to :', df_books[df_books.book_id == id]['original_title'].values[0])

iid = train_set.to_inner_iid(id)

dtypes = np.dtype([
          ('original_title', str),
          ('authors', str),
          ('sim', float),
          ])

simbooks = pd.DataFrame(np.empty(0, dtype=dtypes))

book_embedding = algo.qi
current_book = book_embedding[iid, :].reshape(1, -1)
total_books = book_embedding.shape[0]
for i in range(total_books):
  if i!= iid:
    sim = cosine_similarity(current_book, book_embedding[i,:].reshape(1, -1))
    rawid = train_set.to_raw_iid(i)
    book_title = df_books[df_books.book_id == rawid]['original_title'].values[0]
    authors = df_books[df_books.book_id == rawid]['authors'].values[0]

    simbooks = simbooks.append({'original_title' : book_title, 'authors' : authors, 
                      'sim' : sim }, ignore_index = True)
    
simbooks = simbooks.sort_values('sim', ascending = False)

simbooks.head(20)
# Out:
# SVD Similar books to : The Joy of Cooking
#                                          original_title  \
# 8361                                      Castle Roogna
# 6677                                   Just Like Heaven
# 7492                                A Theory of Justice
# 4648                                A Fistful of Charms
# 5533                            A Long Way From Chicago
# 8684                                             Chomp!
# 5622                                  Calvin and Hobbes
# 6936                      Miracles: A Preliminary Study
# 1891                                    Alex Cross, Run
# 1669                       Same Kind of Different as Me
# 7387                                            Hidden
# 8750                                 16 Lighthouse Road
# 7994                                 Hammer of the Gods
# 7792                    The Case of Charles Dexter Ward
# 2626                                    Shadows of Self
# 3669                                 Mad About Madeline
# 6296  My Story: "A Child Called It", "The Lost Boy",...
# 2309                                 Last Chance Saloon
# 2194                                Requiem for a Dream
# 977                           Everything Is Illuminated
#
#                                                 authors  \
# 8361                                      Piers Anthony
# 6677                                        Julia Quinn
# 7492                                         John Rawls
# 4648                                       Kim Harrison
# 5533                                       Richard Peck
# 8684                                       Carl Hiaasen
# 5622                       Bill Watterson, G.B. Trudeau
# 6936                                         C.S. Lewis
# 1891                                    James Patterson
# 1669               Ron Hall, Denver Moore, Lynn Vincent
# 7387                                      Kendra Elliot
# 8750                                    Debbie Macomber
# 7994                                      Stephen Davis
# 7792                                     H.P. Lovecraft
# 2626                                  Brandon Sanderson
# 3669                                   Ludwig Bemelmans
# 6296                                        Dave Pelzer
# 2309                                       Marian Keyes
# 2194  Hubert Selby Jr., Darren Aronofsky, Richard Price
# 977                                Jonathan Safran Foer
#
#                           sim
# 8361  [[0.22868941007657373]]
# 6677  [[0.22495189137348642]]
# 7492  [[0.19892125680483588]]
# 4648  [[0.19661862783835354]]
# 5533  [[0.19628196306328455]]
# 8684   [[0.1947688888149388]]
# 5622  [[0.18854213347502094]]
# 6936  [[0.18633307904752136]]
# 1891   [[0.1808204864152476]]
# 1669  [[0.18075409799237563]]
# 7387  [[0.17886331952357373]]
# 8750  [[0.17792530787658034]]
# 7994   [[0.1771368302897372]]
# 7792  [[0.17702191455710825]]
# 2626  [[0.17422183895275958]]
# 3669  [[0.17413403137005012]]
# 6296   [[0.1738306864981009]]
# 2309  [[0.17338856848616718]]
# 2194  [[0.17132770144232823]]
# 977   [[0.17095590625800894]]
